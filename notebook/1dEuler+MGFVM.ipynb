# %% [markdown]
# # 1次元圧縮性Euler方程式
# ## 支配方程式
# $\displaystyle \frac{\partial Q}{\partial t} + \frac{\partial F}{\partial x} = 0$
#
# $\displaystyle e= \frac{1}{2}\rho u^2 + \frac{p}{\gamma-1}$

# %% [markdown]
# where
# $Q = \left[
# \begin{matrix}
# \rho \\
# \rho u \\
# e
# \end{matrix}
# \right]$
#
# $F = \left[
# \begin{matrix}
# \rho u \\
# \rho u^2 + p \\
# (E + p)u
# \end{matrix}
# \right]$
#
# $\rho$ is density of fluid,
# $u$ is flow velocity,
# $e$ is total energy per unit mass, and
# $p$ is pressure.

# %% [markdown]
# ## Flux jacobian
# $\displaystyle \frac{\partial F}{\partial Q} = A = P\Lambda P^{-1}$
#
# where
#
# $\displaystyle P=\left[
# \begin{matrix}
# 1 & 1 & 1 \\
# u-a & u & u+a \\
# H-au & \frac{u^2}{2} & H+au
# \end{matrix}
# \right]$
#
# $\displaystyle \Lambda = \left[
# \begin{matrix}
# u-a & 0 & 0 \\
# 0 & u & 0 \\
# 0 & 0 & u+a
# \end{matrix}
# \right]$
#
# $\displaystyle P^{-1}=\left[
# \begin{matrix}
# \frac{1}{2}\left( \alpha_1 + \frac{u}{a} \right) & -\frac{1}{2}\left( \alpha_2 u + \frac{1}{a} \right) & \frac{\alpha_2}{2} \\
# 1-\alpha_1 & \alpha_2u & -\alpha_2 \\
# \frac{1}{2}\left( \alpha_1 - \frac{u}{a} \right) & -\frac{1}{2}\left( \alpha_2 u - \frac{1}{a} \right) & \frac{\alpha_2}{2} \\
# \end{matrix}
# \right]$
#
# $\displaystyle \alpha_1 =
# \frac{\left( \gamma - 1 \right) u^2}
# {2a^2}$
#
# $\displaystyle \alpha_2 =
# \frac{\left( \gamma - 1 \right)}
# {a^2}$

# %% [markdown]
# $H$ is total enthalpy, $T$ is temperature, and $a$ is speed of sound.
#
# $\displaystyle H = \rho c_p T = \frac{\gamma}{\gamma - 1} \rho T = \frac{\gamma}{\gamma - 1}p$
# $\displaystyle T = \frac{p}{\rho}$
# $\displaystyle a = \sqrt{ \gamma \frac{p}{\rho} }$

# %% [markdown]
# $\gamma = 1.4$ is heat capacity ratio.

# %% [markdown]
# ## descritization
# $\displaystyle \int_\Omega \left( \frac{\partial Q_i}{\partial t} + \frac{\partial F_i}{\partial x} \right) d\Omega=\int_\Omega \tilde{ \nabla } \tilde{ F }_i d\Omega=0$

# %% [markdown]
# where
# $\displaystyle \tilde{ \nabla } = \left( \frac{\partial }{\partial t}, \frac{\partial }{\partial x}\right)$
# $\displaystyle \tilde{ F }_i = \left( Q_i, F_i \right)$

# %% [markdown]
# $\displaystyle \int_\Omega \tilde{ \nabla } \tilde{ F }_i d\Omega = \int_{\partial \Omega} \tilde{ F }_i \vec{n} d\left( \partial \Omega \right) = 0$
# where
# $\vec{ n } =\left( n_t, n_x \right)$

# %% [markdown]
# $\displaystyle \int_{\partial \Omega} \tilde{ F }_i \vec{n} d\left( \partial \Omega \right)
# = \sum_{ j \in \partial \Omega  } \tilde{F}_{ij} \vec{n}_j \delta (\partial \Omega)_j
# = \sum_{ j \in \partial \Omega  } \tilde{F}_{ij} \vec{\tilde{n}}_j = 0
# $
# where $\vec{\tilde{n}}_j = \vec{n}_j \delta (\partial \Omega)_j$

# %% [markdown]
# $\displaystyle j=1 : \left( t=n, x=i \right)$
# $\displaystyle \tilde{F}_{i1} \vec{\tilde{n}}_1 = \left( Q_{i}^{n}, F_{i}^{n} \right) \cdot \left( -\Delta x_i^{n}, 0 \right) = -Q_{i}^{n}\Delta x_i^{n}$

# %% [markdown]
# $\displaystyle j=2 : \left( t=n+\frac{1}{2}, x=i+\frac{1}{2} \right)$
# $\displaystyle \tilde{F}_{i2} \vec{\tilde{n}}_2$
# $= \left( Q_{i+\frac{1}{2}}^{n+\frac{1}{2}}, F_{i+\frac{1}{2}}^{n+\frac{1}{2}} \right) \cdot \left( -\delta x_{i+\frac{1}{2}}^{n+\frac{1}{2}}, \Delta t \right) = - Q_{i+\frac{1}{2}}^{n+\frac{1}{2}} \delta x_{i+\frac{1}{2}}^{n+\frac{1}{2}} + F_{i+\frac{1}{2}}^{n+\frac{1}{2}} \Delta t$

# %% [markdown]
# $\displaystyle j=3 : \left( t=n, x=i \right)$
# $\displaystyle \tilde{F}_{i3} \vec{\tilde{n}}_3 = \left( Q_{i}^{n+1}, F_{i}^{n+1} \right) \cdot \left( \Delta x_i^{n+1}, 0 \right) = Q_{i}^{n+1}\Delta x_i^{n+1}$

# %% [markdown]
# $\displaystyle j=4 : \left( t=n+\frac{1}{2}, x=i-\frac{1}{2} \right)$
# $\displaystyle \tilde{F}_{i4} \vec{\tilde{n}}_4$
# $= \left( Q_{i-\frac{1}{2}}^{n+\frac{1}{2}}, F_{i-\frac{1}{2}}^{n+\frac{1}{2}} \right) \cdot \left( \delta x_{i-\frac{1}{2}}^{n+\frac{1}{2}}, -\Delta t \right) = Q_{i-\frac{1}{2}}^{n+\frac{1}{2}} \delta x_{i-\frac{1}{2}}^{n+\frac{1}{2}} - F_{i-\frac{1}{2}}^{n+\frac{1}{2}} \Delta t$

# %% [markdown]
# where
# $\displaystyle Q^{n+\frac{1}{2}} = \frac{1}{2}\left( Q^n + Q^{n+1} \right)$
# $\displaystyle F^{n+\frac{1}{2}} = \frac{1}{2}\left( F^n + F^{n+1} \right)$

# %% [markdown]
# $\displaystyle Q_{\frac{i+j}{2}} = Roe\left( Q_i , Q_j \right) = \left[
# \begin{matrix}
# \rho_{roe} \\
# \rho_{roe} u_{roe} \\
# e_{roe}
# \end{matrix}
# \right]$
#
# $\displaystyle F_{\frac{i+j}{2}} = \frac{1}{2} \left( F_i + F_{j} \right) - \frac{1}{2} A_{roe} \left( Q_j - Q_i \right)$
#
# $e_{roe}=\frac{1}{\gamma}H_{roe} + \frac{1}{2}\rho_{roe}u_{roe}^2$

# %% [markdown]
# $A^{roe} = P\Lambda P^{-1}$
# Note that $P$, $\Lambda$ and $P^{-1}$ are calculated from the variable of roe average.

# %% [markdown]
# ### Roe average
# $\rho_{roe} = \sqrt{\rho_i \rho_j}$
# $\displaystyle u_{roe} = \frac{\sqrt{\rho_i} u_i + \sqrt{\rho_j} u_j}{\sqrt{\rho_i} + \sqrt{\rho_j} }$
# $\displaystyle H_{roe} = \frac{\sqrt{\rho_i} H_i + \sqrt{\rho_j} H_j}{\sqrt{\rho_i} + \sqrt{\rho_j} }$
# $\displaystyle a_{roe} = \sqrt{ \left( \gamma - 1 \right) \left( H_{roe} - \frac{u_{roe}^2}{2} \right) }$

# %% [markdown]
# ## Time step
# $\displaystyle L\left( Q_i^{n + 1}, Q_i^{n}\right) =
# \frac{1}{\Delta t} \left(
#         Q_i^{n+1}
#         - \frac{ \Delta x_i^{n} }{ \Delta x_i^{n+1} } Q_i^{n}
#     \right)
#     +
#     \frac{1}{\Delta x_i^{n+1}} \left(
#         F_{i + \frac{1}{2}}^{ n + \frac{1}{2}}
#       - F_{i - \frac{1}{2}}^{ n + \frac{1}{2}}
#     \right)
#     - \frac{1}{\Delta t} \left(
#         \frac{ \delta x_{i + \frac{1}{2}}^{ n + \frac{1}{2}} }
#              {\Delta x_{i}^{ n + 1}}
#         Q_{i + \frac{1}{2}}^{ n + \frac{1}{2}}
#       - \frac{ \delta x_{i - \frac{1}{2}}^{ n + \frac{1}{2}} }
#              {\Delta x_{i}^{ n + 1}}
#         Q_{i - \frac{1}{2}}^{ n + \frac{1}{2}}
#     \right)
# $

# %% [markdown]
# $\displaystyle \frac{\partial Q}{\partial \tau} = -L\left( Q_i^{n+1}, Q_i^{n}\right)$

# %% [markdown]
# ### explicit euler
# $\displaystyle Q_i^{\left( n+1 \right)\left( \nu+1 \right)} = Q_i^{\left( n+1 \right)\left( \nu \right)} -\Delta \tau L\left( Q_i^{\left( n+1 \right)\left( \nu \right)}, Q_i^{n}\right)$
# where
# $Q_i^{\left( n+1 \right)\left( 0 \right)} = Q_i^{n}$

# %% [markdown]
# where $\left( , \right)$ means dot product of all region.
# $\left( g_a, g_b\right) = \sum_{i=1}^{N} \sum_{j=1}^{3} g_{aij} g_{bij}$
# Note that the result is scalar variable.

# %% [markdown]
# where
# $b_1 = 17$
# $b_2 = -16$
# $c_2 = \frac{1}{32}$
# $\alpha = \left\{
# \begin{array}{ll}
# 2.1 & (CFL \leq 1) \\
# \frac{1.22}{CFL}-0.07CFL+0.95 & \left( 1.0 < CFL < 10.0 \right)
# \end{array}
# \right.
# $

# %% [markdown]
# ### RRK2
# $\displaystyle g_1 = -\Delta \tau L\left( Q_i^{\left( n+1 \right)\left( \nu \right)}, Q_i^{n}\right)$
# $\displaystyle g_2 = -\Delta \tau L\left( Q_i^{\left( n+1 \right)\left( \nu \right)} + c_2g_1, Q_i^{n}\right)$
# $g_3=b_1g_1 + b_2g_2$
# $Q_i^{\left( n+1 \right)\left( \nu + 1\right)} = Q_i^{\left( n+1 \right)\left( \nu \right)} + \frac{2g_1\left( g_1, g_3\right) - g_3\left( g_1, g_1\right)}{\left( g_3, g_3\right)}$
# $Q_i^{\left( n+1 \right)\left( 0 \right)} = Q_i^{n}$

# %%
from math import sqrt
import numpy as np

# constant
L=3 # [m]
U=5 # [m/s]
P=101325 # [Pa]
Rho = 1.293 # [m^3/kg]
T=298 # [K]

g = 1.4
g1 = g - 1

non_L = 1
non_U = 1
non_A = 1
non_Rho = 1
non_P = non_Rho / g * non_A**2
non_T = non_P / non_Rho
non_e = 1/2 * non_Rho * non_U**2 + non_P / g1
print(non_P)
print(non_e)
def e2p(Q):
    rho = Q[:, 0]
    u = Q[:, 1] / Q[:, 0]
    e = Q[:, 2]
    p = g1 * ( e - 1/2 * rho * u**2 )
    return p

def e2T(Q):
    p = e2p(Q)
    rho = Q[:, 0]
    T = p / rho
    return T

# paramter for rrk2
b1 = 17
b2 = -16
c2 = 1/32
# Out:
# 0.7142857142857143
# 2.2857142857142865

# %%
def q2b(q):
    rho = q[0]
    u = q[1] / q[0]
    e = q[2] 
    p = g1 * ( e - (rho * u**2 / 2) )
    return rho, u, e, p

def q2f(q):
    (rho, u, e, p) = q2b(q)
    F = np.zeros(3)
    F[0] = rho * u
    F[1] = rho * u**2 + p
    F[2] = (e + p) * u
    return F

def entropy_fix(a, epsilon=0.01):
    abs_a = abs(a)
    if ( abs_a < epsilon ):
        mod_a = 1/2* (abs_a**2/epsilon + epsilon)
    else:
        mod_a = abs_a
    return mod_a

def get_roe_average(qi, qj):
    ( rho_i, u_i, e_i, p_i ) = q2b(qi)
    ( rho_j, u_j, e_j, p_j ) = q2b(qj)
    H_i = ( g / g1 ) * p_i / rho_i + u_i**2 / 2
    H_j = ( g / g1 ) * p_j / rho_j + u_j**2 / 2
    # print(qi, qj)
    rho = sqrt(rho_i * rho_j)
    u = ( sqrt(rho_i) * u_i + sqrt(rho_j) * u_j ) / (sqrt(rho_i) + sqrt(rho_j) )
    H = ( sqrt(rho_i) * H_i + sqrt(rho_j) * H_j ) / (sqrt(rho_i) + sqrt(rho_j) )
    a_sq = g1 * ( H - u**2 /2 )
    if a_sq < 0:
        print(qi, qj)
        print(rho, u, H, a_sq)
        raise ValueError
    # a = sqrt( g1 * ( H - u**2/2 ) )
    a = sqrt(a_sq)
    return rho, u, H, a

def roe_fds(qi, qj):
    rho, u, H, a = get_roe_average(qi, qj)
    
    P = np.zeros((3,3))
    invP = np.zeros((3,3))
    L = np.zeros((3,3))
    
    a1 = ( g1 * u**2 ) / (2 * a**2)
    a2 = g1 / a**2
    
    P[0, 0] = 1
    P[0, 1] = 1
    P[0, 2] = 1
    P[1, 0] = u - a
    P[1, 1] = u
    P[1, 2] = u + a
    P[2, 0] = H - a * u
    P[2, 1] = u**2 / 2
    P[2, 2] = H + a * u

    L[0, 0] = entropy_fix(u - a)
    L[1, 1] = entropy_fix(u)
    L[2, 2] = entropy_fix(u + a) 
    
    invP[0, 0] = 1/2 * (a1 + u/a)
    invP[0, 1] = -1/2 * (a2*u + 1/a)
    invP[0, 2] = a2 / 2
    invP[1, 0] = 1 - a1
    invP[1, 1] = a2 * u
    invP[1, 2] = -a2
    invP[2, 0] = 1/2*(a1 - u/a)
    invP[2, 1] = -1/2 * (a2*u - 1/a)
    invP[2, 2] = a2 / 2

    dq = qj - qi
    dF = np.dot(P, np.dot(L, np.dot(invP, dq)))
    
    F_i = q2f(qi)
    F_j = q2f(qj)
    #print(qi, qj)
    #print(F_i, F_j)
    roeF = 1/2 * (F_i + F_j) - 1/2*dF
    return roeF

# %%
def flux(Q, qB):
    F = np.zeros((n+1, 3))
    for j in range(n+1):
        if ( j == 0 ):
            qi = qB[:, 0]
        else:
            qi = Q[j-1, :]
            
        if ( j == n):
            qj = qB[:, 1]
        else:
            qj = Q[j  , :]
            
        F[j, :] = roe_fds(qi, qj)

    return F


def roeQ(Q, qB):
    roeQ = np.zeros((n+1, 3))
    for j in range(n+1):
        if ( j == 0 ):
            qi = qB[:, 0]
        else:
            qi = Q[j-1, :]
            
        if ( j == n ):
            qj = qB[:, 1]
        else:
            qj = Q[j  , :]
        
        rho, u, H, a = get_roe_average(qi, qj)
        m = rho*u
        p = a**2 * rho / g
        e = rho*H - p
        # e = 1/2*rho*u**2 + rho/g1 * (H - u**2/2) # H = (e+p)/rho
        roeQ[j, 0] = rho
        roeQ[j, 1] = m
        roeQ[j, 2] = e
        # print(rho, u, m, H, a, e)
    return roeQ

# %%
def update_dx_from_edge(x_e):
    dx = np.diff(x_e)
    return dx

def update_x_from_edge(x_e):
    x_c = np.zeros(n)
    for i in range(n):
        x_c[i] = (x_e[i] + x_e[i+1])/2
    return x_c
   
def update_x(t, x_e_0=None, omega=1, coef=0.4, fixed=False):
    x_e = np.zeros(n+1)
    avg_dx = non_L / n
    avg_rad = omega*t
    avg_rad_n = omega*(t-1)
    
    delta_x = np.zeros(n+1)
    for j in range(n+1):
        if fixed or ( j == 0 ) or ( j == n ):
            x_e[j] = j * avg_dx
        else:
            x_e[j] = j * avg_dx + coef*( avg_dx )*np.sin( avg_rad   + j )
            x_e_n  = j * avg_dx + coef*( avg_dx )*np.sin( avg_rad_n + j)
            delta_x[j] = x_e[j] - x_e_n
        
    x_c = update_x_from_edge(x_e)
    dx = update_dx_from_edge(x_e)
    if ( t == 0 ):
        delta_x = np.zeros(n+1)
    return x_c, x_e, dx, delta_x

# %%
test_Kmax = 1000
test_x_e = np.zeros((test_Kmax, 4))
xe1 = 1
for test_k in range(test_Kmax):
    _, x_e, _, _ = update_x(t=test_k)
    for test_l in range(4):
        test_x_e[test_k, test_l] = x_e[-test_l-1]

plt.scatter(test_x_e[:, 0], np.arange(test_Kmax))
plt.scatter(test_x_e[:, 1], np.arange(test_Kmax))
plt.scatter(test_x_e[:, 2], np.arange(test_Kmax))
plt.scatter(test_x_e[:, 3], np.arange(test_Kmax))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 5
#       3 xe1 = 1
#       4 for test_k in range(test_Kmax):
# ----> 5     _, x_e, _, _ = update_x(t=test_k)
#       6     for test_l in range(4):
#       7         test_x_e[test_k, test_l] = x_e[-test_l-1]
#
# Cell In[5], line 12, in update_x(t, x_e_0, omega, coef, fixed)
#      11 def update_x(t, x_e_0=None, omega=1, coef=0.4, fixed=False):
# ---> 12     x_e = np.zeros(n+1)
#      13     avg_dx = non_L / n
#      14     avg_rad = omega*t
#
# NameError: name 'n' is not defined

# %%
Tmax = 3 / (L/U) # [-] non-dimentional time
dt = 0.0001
n = 100

x_c, x_e, dx, delta_x = update_x(t=0)
    
# initial condition
Q = np.zeros((n, 3), np.float64)
Q[:, 0] = non_Rho
Q[:, 1] = non_Rho * 0
Q[:, 2] = 1/2*non_Rho*0**2 + ( non_P ) / g1

for i in range(n):
    if ( x_c[i] > 0.5 ):
        Q[i, 0] = 1/8*non_Rho
        Q[i, 2] = 1/2*non_Rho*0**2 + ( non_P / 10 ) / g1
        # pass

# %%
def calc_CFL(Q, dx, dt):
    CFL = 0
    for i in range(n):
        qi = Q[i, :]
        ( rho, u, e, p ) = q2b(qi)
        a = sqrt(g * p / rho)
        CFL_i = max(abs(u), abs(u-a), abs(u+a)) * dt / dx[i]
        CFL = max(CFL, CFL_i)
    return CFL

def set_dtau(Q, dx, dt):
    CFL = calc_CFL(Q, dx, dt)
    if ( CFL < 1 ):
        alpha = 2.1
    else:
        alpha = 1.22/CFL - 0.07*CFL + 0.95
    dtau = alpha*dt
    return dtau

# %%
import matplotlib.pyplot as plt
# plt.scatter(x_c, Q[:, 2])

# %%
def bc_refrect(q):
    rho, u, e, p = q2b(q)
    qB = np.zeros(3)
    qB[0] = rho
    qB[1] = - rho * u
    qB[2] = e
    return qB

# %% [markdown]
# ## Time step
# $\displaystyle L\left( Q_i^{n + 1}, Q_i^{n}\right) =
# \frac{1}{\Delta t} \left(
#         Q_i^{n+1}
#         - \frac{ \Delta x_i^{n} }{ \Delta x_i^{n+1} } Q_i^{n}
#     \right)
#     +
#     \frac{1}{\Delta x_i^{n+1}} \left(
#         F_{i + \frac{1}{2}}^{ n + \frac{1}{2}}
#       - F_{i - \frac{1}{2}}^{ n + \frac{1}{2}}
#     \right)
#     - \frac{1}{\Delta t} \left(
#         \frac{ \delta x_{i + \frac{1}{2}}^{ n + \frac{1}{2}} }
#              {\Delta x_{i}^{ n + 1}}
#         Q_{i + \frac{1}{2}}^{ n + \frac{1}{2}}
#       - \frac{ \delta x_{i - \frac{1}{2}}^{ n + \frac{1}{2}} }
#              {\Delta x_{i}^{ n + 1}}
#         Q_{i - \frac{1}{2}}^{ n + \frac{1}{2}}
#     \right)
# $

# %%
plot_dt = 100
Nmax = int(0.25/dt)#int(Tmax / dt)
Pmax = int(Nmax / plot_dt )
fg = True

def calc_L(Qn1, Qn, dxn1, dxn, delta_x, dt):
    qBn  = np.zeros((3, 2))
    qBn1 = np.zeros((3, 2))
    # set boundary 
    qBn[:, 0]  = bc_refrect(Qn[0, :])
    qBn[:, 1]  = bc_refrect(Qn[n-1, :])
    qBn1[:, 0] = bc_refrect(Qn1[0, :])
    qBn1[:, 1] = bc_refrect(Qn1[n-1, :])
    
    Fn  = flux(Qn , qBn)
    Fn1 = flux(Qn1, qBn1)
    Fn12 = (Fn + Fn1) / 2
    
    Qijn  = roeQ(Qn,  qBn)
    Qijn1 = roeQ(Qn1, qBn1)
    Qij12 = (Qijn + Qijn1) / 2
    L = np.zeros((n, 3))
    for i in range(n):
        m1 = i
        p1 = i + 1
        L[i, :] = 1/dt * ( Qn1[i, :] - dxn[i]/dxn1[i] * Qn[i, :] ) \
                + 1/dxn1[i] * ( Fn12[p1, :] - Fn12[m1, :] ) \
                - 1/dt * ( delta_x[p1]/dxn1[i] * Qij12[p1, :] - delta_x[m1]/dxn1[i] * Qij12[m1, :])

    return L

def rrk2(Q):
    def dot(a, b):
        return np.sum(a*b)
        
    Q_store = np.zeros((n, 3, Pmax))
    x_e_0 = None
    retry = 100
    fixed_grid=fg
    epsilon = 10**(-14)
    _, x_e_n, dxn, _ = update_x(t=0*dt, x_e_0=None, fixed=fixed_grid)
    Qn = Q
    for k in range(Nmax):
        _, x_e_n1, dxn1, _ = update_x(t=(k+1)*dt, x_e_0=x_e_0, fixed=fixed_grid)
        delta_x = x_e_n1 - x_e_n
        dtau = set_dtau(Qn, dxn1, dt)
        # print(np.max(delta_x))
        # iteration
        for count in range(retry + 1):
            if ( count == 0 ):
                Qn1 = Qn
                
            s1 = -dtau * calc_L(Qn1, Qn, dxn1, dxn, delta_x, dt) # s1 == g1
            s2 = -dtau * calc_L(Qn1 + c2 * s1, Qn, dxn1, dxn, delta_x, dt) # s1 == g1
            s3 = b1*s1 + b2*s2
            ss11 = dot(s1, s1)
            ss13 = dot(s1, s3)
            ss33 = dot(s3, s3)
            dQ = (2*s1*ss13 - s3*ss11) / ss33
            Qn1 = Qn1 + dQ
            
            res_avg = np.sqrt(np.sum((dQ)**2) / (3*n))
            res_max = np.sqrt(np.max(dQ**2))
            res = max(res_avg, res_max)

            if ( res < epsilon ):
                break
                
            if ( count == retry ):
                print(k, "not converge")
                print(res)
                return Q_store

        if ( k % plot_dt == 0 ):
            print(k, count, res)
            m = int(k / plot_dt)
            Q_store[:, 0, m] = Qn1[:, 0]
            Q_store[:, 1, m] = Qn1[:, 1]
            Q_store[:, 2, m] = Qn1[:, 2]

        # prepare for next time step
        Qn = Qn1
        x_e_n = x_e_n1
        dxn = dxn1
            
    return Q_store
    
Qsr = rrk2(Q)
# Out:
# 0 8 2.572153514954359e-15
# 100 8 1.4846640089430088e-15
# 200 8 1.2145979397318558e-15
# 300 7 9.471010953801397e-15
# 400 7 9.082749080941425e-15
# 500 7 7.964462713820112e-15
# 600 7 7.69191790936561e-15
# 700 7 7.020622728483412e-15
# 800 7 6.705361967232112e-15
# 900 7 6.4985213812261055e-15
# 1000 7 6.294514857880179e-15
# 1100 7 6.439076689504975e-15
# 1200 7 6.1014624430842125e-15
# 1300 7 5.731510279217206e-15
# 1400 7 5.693875380689989e-15
# 1500 7 5.788768692074236e-15
# 1600 7 5.499537871916053e-15
# 1700 7 5.5847087924655605e-15
# 1800 7 5.457367959199207e-15
# 1900 7 5.291317065422357e-15
# 2000 7 5.607270635938423e-15
# 2100 7 5.224886434363337e-15
# 2200 7 5.408062663445592e-15
# 2300 7 5.3043335401642536e-15
# 2400 7 5.230556512015534e-15

# %%
rho_plt = Qsr[:, 0, :]
u_plt = Qsr[:, 1, :] / Qsr[:, 0, :] 
p_plt = ( Qsr[:, 2, :] - 1/2 * rho_plt * u_plt**2 ) / g1

from matplotlib.animation import ArtistAnimation
from IPython import display 

fig = plt.figure(figsize=(5,10))
ax1 = fig.add_subplot(311)
ax2 = fig.add_subplot(312)
ax3 = fig.add_subplot(313)
plt.xlim(0, 1)
# ax1.set_ylim(0, int(np.max(rho_plt)+0.5))
# ax2.set_ylim(-1, 1)
# ax3.set_ylim(0, 2)


frames = []
x = x_c
y1 = rho_plt
y2 = u_plt
y3 = p_plt
num_frames = rho_plt.shape[1]
for i in range(num_frames):
    x, _, _, _ = update_x(t=(i*plot_dt+1)*dt, fixed=fg)
    frame1 = ax1.plot(x, y1[:, i], label='Density', color='blue')
    frame2 = ax2.plot(x, y2[:, i], label='Velocity', color='orange')
    frame3 = ax3.plot(x, y3[:, i], label='Pressure', color='green')
    
    if ( i == 0 ):
        ax1.legend()
        ax2.legend()
        ax3.legend()
    frames.append(frame1 + frame2 + frame3)
    
# 描画
ani = ArtistAnimation(fig, frames, interval=100)
html = display.HTML(ani.to_jshtml())
display.display(html)
plt.close()
# Out:
# <link rel="stylesheet"
# href="https://maxcdn.bootstrapcdn.com/font-awesome/4.4.0/css/font-awesome.min.css">
# <script language="javascript">
#   function isInternetExplorer() {
#     ua = navigator.userAgent;
#     /* MSIE used to detect old browsers and Trident used to newer ones*/
#     return ua.indexOf("MSIE ") > -1 || ua.indexOf("Trident/") > -1;
#   }
#
#   /* Define the Animation class */
#   function Animation(frames, img_id, slider_id, interval, loop_select_id){
#     this.img_id = img_id;
#     this.slider_id = slider_id;
#     this.loop_select_id = loop_select_id;
#     this.interval = interval;
#     this.current_frame = 0;
#     this.direction = 0;
#     this.timer = null;
#     this.frames = new Array(frames.length);
#
#     for (var i=0; i<frames.length; i++)
#     {
#      this.frames[i] = new Image();
#      this.frames[i].src = frames[i];
#     }
#     var slider = document.getElementById(this.slider_id);
#     slider.max = this.frames.length - 1;
#     if (isInternetExplorer()) {
#         // switch from oninput to onchange because IE <= 11 does not conform
#         // with W3C specification. It ignores oninput and onchange behaves
#         // like oninput. In contrast, Microsoft Edge behaves correctly.
#         slider.setAttribute('onchange', slider.getAttribute('oninput'));
#         slider.setAttribute('oninput', null);
#     }
#     this.set_frame(this.current_frame);
#   }
#
#   Animation.prototype.get_loop_state = function(){
#     var button_group = document[this.loop_select_id].state;
#     for (var i = 0; i < button_group.length; i++) {
#         var button = button_group[i];
#         if (button.checked) {
#             return button.value;
#         }
#     }
#     return undefined;
#   }
#
#   Animation.prototype.set_frame = function(frame){
#     this.current_frame = frame;
#     document.getElementById(this.img_id).src =
#             this.frames[this.current_frame].src;
#     document.getElementById(this.slider_id).value = this.current_frame;
#   }
#
#   Animation.prototype.next_frame = function()
#   {
#     this.set_frame(Math.min(this.frames.length - 1, this.current_frame + 1));
#   }
#
#   Animation.prototype.previous_frame = function()
#   {
#     this.set_frame(Math.max(0, this.current_frame - 1));
#   }
#
#   Animation.prototype.first_frame = function()
#   {
#     this.set_frame(0);
#   }
#
#   Animation.prototype.last_frame = function()
#   {
#     this.set_frame(this.frames.length - 1);
#   }
#
#   Animation.prototype.slower = function()
#   {
#     this.interval /= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.faster = function()
#   {
#     this.interval *= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.anim_step_forward = function()
#   {
#     this.current_frame += 1;
#     if(this.current_frame < this.frames.length){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.first_frame();
#       }else if(loop_state == "reflect"){
#         this.last_frame();
#         this.reverse_animation();
#       }else{
#         this.pause_animation();
#         this.last_frame();
#       }
#     }
#   }
#
#   Animation.prototype.anim_step_reverse = function()
#   {
#     this.current_frame -= 1;
#     if(this.current_frame >= 0){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.last_frame();
#       }else if(loop_state == "reflect"){
#         this.first_frame();
#         this.play_animation();
#       }else{
#         this.pause_animation();
#         this.first_frame();
#       }
#     }
#   }
#
#   Animation.prototype.pause_animation = function()
#   {
#     this.direction = 0;
#     if (this.timer){
#       clearInterval(this.timer);
#       this.timer = null;
#     }
#   }
#
#   Animation.prototype.play_animation = function()
#   {
#     this.pause_animation();
#     this.direction = 1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_forward();
#     }, this.interval);
#   }
#
#   Animation.prototype.reverse_animation = function()
#   {
#     this.pause_animation();
#     this.direction = -1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_reverse();
#     }, this.interval);
#   }
# </script>
#
# <style>
# .animation {
#     display: inline-block;
#     text-align: center;
# }
# input[type=range].anim-slider {
#     width: 374px;
#     margin-left: auto;
#     margin-right: auto;
# }
# .anim-buttons {
#     margin: 8px 0px;
# }
# .anim-buttons button {
#     padding: 0;
#     width: 36px;
# }
# .anim-state label {
#     margin-right: 8px;
# }
# .anim-state input {
#     margin: 0;
#     vertical-align: middle;
# }
# </style>
#
# <div class="animation">
#   <img id="_anim_imgfcf86fa0e10244889e05fbd71554633b">
#   <div class="anim-controls">
#     <input id="_anim_sliderfcf86fa0e10244889e05fbd71554633b" type="range" class="anim-slider"
#            name="points" min="0" max="1" step="1" value="0"
#            oninput="animfcf86fa0e10244889e05fbd71554633b.set_frame(parseInt(this.value));">
#     <div class="anim-buttons">
#       <button title="Decrease speed" aria-label="Decrease speed" onclick="animfcf86fa0e10244889e05fbd71554633b.slower()">
#           <i class="fa fa-minus"></i></button>
#       <button title="First frame" aria-label="First frame" onclick="animfcf86fa0e10244889e05fbd71554633b.first_frame()">
#         <i class="fa fa-fast-backward"></i></button>
#       <button title="Previous frame" aria-label="Previous frame" onclick="animfcf86fa0e10244889e05fbd71554633b.previous_frame()">
#           <i class="fa fa-step-backward"></i></button>
#       <button title="Play backwards" aria-label="Play backwards" onclick="animfcf86fa0e10244889e05fbd71554633b.reverse_animation()">
#           <i class="fa fa-play fa-flip-horizontal"></i></button>
#       <button title="Pause" aria-label="Pause" onclick="animfcf86fa0e10244889e05fbd71554633b.pause_animation()">
#           <i class="fa fa-pause"></i></button>
#       <button title="Play" aria-label="Play" onclick="animfcf86fa0e10244889e05fbd71554633b.play_animation()">
#           <i class="fa fa-play"></i></button>
#       <button title="Next frame" aria-label="Next frame" onclick="animfcf86fa0e10244889e05fbd71554633b.next_frame()">
#           <i class="fa fa-step-forward"></i></button>
#       <button title="Last frame" aria-label="Last frame" onclick="animfcf86fa0e10244889e05fbd71554633b.last_frame()">
#           <i class="fa fa-fast-forward"></i></button>
#       <button title="Increase speed" aria-label="Increase speed" onclick="animfcf86fa0e10244889e05fbd71554633b.faster()">
#           <i class="fa fa-plus"></i></button>
#     </div>
#     <form title="Repetition mode" aria-label="Repetition mode" action="#n" name="_anim_loop_selectfcf86fa0e10244889e05fbd71554633b"
#           class="anim-state">
#       <input type="radio" name="state" value="once" id="_anim_radio1_fcf86fa0e10244889e05fbd71554633b"
#              >
#       <label for="_anim_radio1_fcf86fa0e10244889e05fbd71554633b">Once</label>
#       <input type="radio" name="state" value="loop" id="_anim_radio2_fcf86fa0e10244889e05fbd71554633b"
#              checked>
#       <label for="_anim_radio2_fcf86fa0e10244889e05fbd71554633b">Loop</label>
#       <input type="radio" name="state" value="reflect" id="_anim_radio3_fcf86fa0e10244889e05fbd71554633b"
#              >
#       <label for="_anim_radio3_fcf86fa0e10244889e05fbd71554633b">Reflect</label>
#     </form>
#   </div>
# </div>
#
#
# <script language="javascript">
#   /* Instantiate the Animation class. */
#   /* The IDs given should match those used in the template above. */
#   (function() {
#     var img_id = "_anim_imgfcf86fa0e10244889e05fbd71554633b";
#     var slider_id = "_anim_sliderfcf86fa0e10244889e05fbd71554633b";
#     var loop_select_id = "_anim_loop_selectfcf86fa0e10244889e05fbd71554633b";
#     var frames = new Array(25);
#
#   frames[0] = "...\
# bGliIHZlcnNpb24zLjcuMSwgaHR0cHM6Ly9tYXRwbG90bGliLm9yZy/bCgiHAAAACXBIWXMAAA9h\
# AAAPYQGoP6dpAABeuElEQ
